# %% [markdown]
# <a href="https://colab.research.google.com/github/sergey185185/Examples/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task  1
# Прочесть с помощью pandas файл california_housing_test.csv,который находится в папке sample_data
# -Посмотеть сколько в нем строк и столбцов
# -Определить какой тип данных имеют столбцы

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv', sep=',')
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0

# %%
df.tail(2)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# # Task 2
# - Проверить есть в файле пустые значения
# - Показать median_house_value где median_income < 2
# - Показать данные в первых 2 столбцах
# - Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.median_house_value
# Out:
# 0       344700.0
# 1       176500.0
# 2       270500.0
# 3       330000.0
# 4        81700.0
#           ...
# 2995    225000.0
# 2996    237200.0
# 2997     62000.0
# 2998    162500.0
# 2999    500001.0
# Name: median_house_value, Length: 3000, dtype: float64

# %%
df['median_house_value']
# Out:
# 0       344700.0
# 1       176500.0
# 2       270500.0
# 3       330000.0
# 4        81700.0
#           ...
# 2995    225000.0
# 2996    237200.0
# 2997     62000.0
# 2998    162500.0
# 2999    500001.0
# Name: median_house_value, Length: 3000, dtype: float64

# %%
df[['median_house_value']]
# Out:
#       median_house_value
# 0               344700.0
# 1               176500.0
# 2               270500.0
# 3               330000.0
# 4                81700.0
# ...                  ...
# 2995            225000.0
# 2996            237200.0
# 2997             62000.0
# 2998            162500.0
# 2999            500001.0
#
# [3000 rows x 1 columns]

# %%
df[['median_house_value','median_income']]
# Out:
#       median_house_value  median_income
# 0               344700.0         6.6085
# 1               176500.0         3.5990
# 2               270500.0         5.7934
# 3               330000.0         6.1359
# 4                81700.0         2.9375
# ...                  ...            ...
# 2995            225000.0         1.1790
# 2996            237200.0         3.3906
# 2997             62000.0         2.2895
# 2998            162500.0         3.2708
# 2999            500001.0         8.5608
#
# [3000 rows x 2 columns]

# %%
df['median_income'] < 2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: median_income, Length: 3000, dtype: bool

# %%
df[df['median_income'] < 2]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 16      -120.81     37.53                15.0        570.0           123.0
# 28      -118.45     34.07                19.0       4845.0          1609.0
# 43      -117.27     34.09                36.0        848.0           186.0
# ...         ...       ...                 ...          ...             ...
# 2943    -121.23     37.96                37.0       2351.0           564.0
# 2964    -118.25     33.94                43.0       1113.0           378.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df['median_income'] < 2][['median_house_value']]
# Out:
#       median_house_value
# 5                67000.0
# 6                67000.0
# 16              181300.0
# 28              350000.0
# 43               79300.0
# ...                  ...
# 2943             57200.0
# 2964             91300.0
# 2985            109400.0
# 2986             85400.0
# 2995            225000.0
#
# [360 rows x 1 columns]

# %%
df.iloc[:,:2]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.loc[:,:'total_rooms']
# Out:
#       longitude  latitude  housing_median_age  total_rooms
# 0       -122.05     37.37                27.0       3885.0
# 1       -118.30     34.26                43.0       1510.0
# 2       -117.81     33.78                27.0       3589.0
# 3       -118.36     33.82                28.0         67.0
# 4       -119.67     36.33                19.0       1241.0
# ...         ...       ...                 ...          ...
# 2995    -119.86     34.42                23.0       1450.0
# 2996    -118.14     34.06                27.0       5257.0
# 2997    -119.70     36.30                10.0        956.0
# 2998    -117.12     34.10                40.0         96.0
# 2999    -119.63     34.42                42.0       1765.0
#
# [3000 rows x 4 columns]

# %%
df[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000 )]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# #Task 3
# - Определить какое максимальное и минимальное значение median_house_value
# - Показать максимальное median_house_value,где median_income=3.1250
# - Указать какая максимальная population,в зоне минимального значения median_house_value

# %%
df.median_house_value.max(),df.median_house_value.min()
# Out:
# (500001.0, 22500.0)

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df[df['median_income'] == 3.1250]['median_house_value'].max()
# Out:
# 233300.0

# %%
df[df['median_house_value'] == df['median_house_value'].min()]['population'].max()
# Out:
# 1230.0

# %% [markdown]
# # Домашнее задание-Seminar № 9
# Задача 40: Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
# import pandas as pd

# %%
# df = pd.read_csv('/content/sample_data/california_housing_train.csv', sep=',')
# df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# df[df['population'] < 500]['median_house_value'].mean()
# Out:
# 206683.83635227982

# %%
# df[
#     (df['population'] > 0) &
#     (df['population'] < 500)
# ].median_house_value.mean()
# Out:
# 206683.83635227982

# %% [markdown]
# Задача 42: Узнать какая максимальная households в зоне минимального значения population

# %%
# df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 4.0

# %% [markdown]
# # Seminar №10
# - Построение графиков

# %% [markdown]
# - Изобразите отношение households к population с
# помощью точечного графика
# - Визуализировать longitude по отношения к
# median_house_value, используя линейный график
# - Представить гистограмму по housing_median_age
# - Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv', sep=',')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import seaborn as sns

# %% [markdown]
# # Изобразите отношение households к population с помощью точечного графика

# %%
sns.scatterplot(data=df, x='households', y='population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %% [markdown]
# # Визуализировать longitude по отношения к median_house_value, используя линейный график

# %%
sns.relplot(data=df, x='longitude', y='median_house_value', kind='line', aspect=4)

# %% [markdown]
# # Представить гистограмму по housing_median_age

# %%
sns.histplot(data=df, x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# # Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
sns.histplot(data=df, x='median_house_value', hue='housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
sns.histplot(data=df, x='median_house_value', y='housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='housing_median_age'>

# %% [markdown]
# # Написать EDA для датасета про пингвинов
#   Необходимо:
# - Использовать 2-3 точечных графика
# - Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# - Использовать PairGrid с типом графика на ваш выбор
# - Изобразить Heatmap
# - Использовать 2-3 гистограммы
#  - Чтобы подключить датасет с
#   пингвинами, воспользуйтесь данным
#   скриптом:
#    - penguins = sns.load_dataset("penguins")
#      penguins.head()

# %%
import seaborn as sns

penguins = sns.load_dataset("penguins")
penguins.dropna(inplace=True)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
penguins.shape
# Out:
# (333, 7)

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='sex',size='body_mass_g')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='flipper_length_mm', y='body_mass_g', hue='sex', size='body_mass_g', style='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins, x='flipper_length_mm', y='body_mass_g', hue='sex', size='body_mass_g', style='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.histplot(data=penguins, x='island', hue='sex')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='island', y='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.relplot(data=penguins, x='body_mass_g', y='sex', kind='line',aspect=4)

# %% [markdown]
# # График 3D через matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
x = penguins.iloc[:, 2]
y = penguins.iloc[:, 3]
z = penguins.iloc[:, 4]
ax.set_xlabel("Длина клюва")
ax.set_ylabel("Ширина клюва")
ax.set_zlabel("Длина ласты")
ax.scatter(x, y, z)
plt.show()

# %% [markdown]
# # PairGrid

# %%
lst = ['bill_length_mm', 'bill_depth_mm',	'flipper_length_mm',	'body_mass_g',	'sex']
g = sns.PairGrid(penguins[lst])
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.scatterplot)

# %% [markdown]
# # Heatmap - 'Тепловые карты'

# %% [markdown]
# - корреляция

# %%
penguins.corr()
# Out:
# <ipython-input-61-203cb6efdfe9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguins.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %% [markdown]
# - Headmap

# %%
sns.heatmap(penguins.corr(), vmin=-1, vmax=1)
# Out:
# <ipython-input-62-465d875adc3c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(penguins.corr(), vmin=-1, vmax=1)
# <Axes: >

# %% [markdown]
# # Создать новый столбец в таблице с
#   пингвинами, который будет отвечать за
#   показатель длины клюва пингвина:
#    high - длинный(от 42)
#    middle - средний(от 35 до 42)
#    low - маленький(до 35)

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'height_group'] = 'hegh'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'height_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'height_group'] = 'low'

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex height_group
# 0         3750.0    Male       middle
# ...

# %%
sns.histplot(data=penguins, x='island', hue='height_group')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %% [markdown]
# # Домашнее Задание Seminar №10
# - Задача 44: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего
# из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без
# get_dummies?

# %%
import random
import pandas as pd
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
print(lst)
print()
data = pd.DataFrame({'whoAmI':lst})
data.loc[data['whoAmI'] == 'robot', 'robot_group'] = '1'
data.loc[data['whoAmI'] != 'robot', 'robot_group'] = '0'
data.loc[data['whoAmI'] == 'human', 'human_group'] = '1'
data.loc[data['whoAmI'] != 'human', 'human_group'] = '0'

data.head(n=20)
# Out:
# ['robot', 'human', 'robot', 'robot', 'robot', 'human', 'human', 'robot', 'human', 'human', 'human', 'robot', 'human', 'robot', 'human', 'human', 'human', 'robot', 'robot', 'robot']
#    whoAmI robot_group human_group
# 0   robot           1           0
# 1   human           0           1
# 2   robot           1           0
# 3   robot           1           0
# 4   robot           1           0
# 5   human           0           1
# 6   human           0           1
# 7   robot           1           0
# 8   human           0           1
# 9   human           0           1
# 10  human           0           1
# 11  robot           1           0
# 12  human           0           1
# 13  robot           1           0
# 14  human           0           1
# 15  human           0           1
# 16  human           0           1
# 17  robot           1           0
# 18  robot           1           0
# 19  robot           1           0
